# %%
#import and authenticate plotly, a graphing library
import plotly
plotly.tools.set_credentials_file(username='wr2299', api_key='oraDkpMv12Ym7uqQkKrS')

import plotly.plotly as py
import plotly.graph_objs as go

# %%
#import pandas to handle the reading of raw data
import pandas

prescriptionsTable = pandas.read_table("two.tsv")

prescriptionsTable
# Out:
#                    State State Code  Number of Scripts / 100 people     2006  \
# 0                Alabama         AL                             NaN  115.600
# 1                 Alaska         AK                             NaN   63.400
# 2                Arizona         AZ                             NaN   74.300
# 3               Arkansas         AR                             NaN   98.300
# 4             California         CA                             NaN   51.000
# 5               Colorado         CO                             NaN   62.200
# 6            Connecticut         CT                             NaN   64.700
# 7               Delaware         DE                             NaN   86.600
# 8   District of Columbia         DC                             NaN   31.700
# 9                Florida         FL                             NaN   79.700
# 10               Georgia         GA                             NaN   79.800
# ...

# %%
#import pandas to handle the reading of raw data
import pandas

deathsTable = pandas.read_table("three.txt")

deathsTable
# Out:
#      Notes  Year  Year Code                 State  State Code  Deaths  \
# 0      NaN  2006       2006               Alabama         1.0     223
# 1      NaN  2006       2006                Alaska         2.0      82
# 2      NaN  2006       2006               Arizona         4.0     539
# 3      NaN  2006       2006              Arkansas         5.0     224
# 4      NaN  2006       2006            California         6.0    3602
# 5      NaN  2006       2006              Colorado         8.0     444
# 6      NaN  2006       2006           Connecticut         9.0     238
# 7      NaN  2006       2006              Delaware        10.0      76
# 8      NaN  2006       2006  District of Columbia        11.0      85
# 9      NaN  2006       2006               Florida        12.0    1951
# 10     NaN  2006       2006               Georgia        13.0     520
# 11     NaN  2006       2006                Hawaii        15.0     148
# ...

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


#prescriptions array from raw data
stateInfo = prescriptionsTable.loc[0]

statePrescriptions = stateInfo[3:14]

statePrescriptions



#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[0 + x*52]]

deathsFinal



# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
)

trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Alabama')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/4.embed" height="525px" width="100%"></iframe>

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[1]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[1 + x*52]]

deathsFinal




# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Alaska')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/6.embed" height="525px" width="100%"></iframe>

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[2]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[2 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Arizona')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/14.embed" height="525px" width="100%"></iframe>

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[3]

statePrescriptions = stateInfo[3:14]

statePrescriptions



#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[3 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Arkansas')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/16.embed" height="525px" width="100%"></iframe>

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[4]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[4 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='California')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/18.embed" height="525px" width="100%"></iframe>

# %%
#import necessary graphing libraries
import plotly.graph_objs as go
import plotly.plotly as py

#include year array
year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[5]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[5 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Colorado')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/8.embed" height="525px" width="100%"></iframe>

# %%
 
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[6]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[6 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Connecticut')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/20.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[7]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[7 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Delaware')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/22.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[8]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[8 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='District of Columbia')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/12.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[9]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[9 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Florida')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/24.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[10]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[10 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Georgia')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/26.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[11]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[11 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Hawaii')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/28.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[12]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[12 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Idaho')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/30.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[13]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[13 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Illinois')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/32.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[14]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[14 + x*52]]

deathsFinal



# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Indiana')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/34.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[15]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[15 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)
#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Iowa')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/36.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[16]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[16 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Kansas')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/38.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[17]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[17 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Kentucky')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/40.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[18]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[18 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Louisiana')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/42.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[19]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[19 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Maine')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/44.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[20]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[20 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Maryland')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/46.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[21]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[21 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

#store traces for graphing
data = [trace, trace1]

#display graph
py.iplot(data, filename='Massachussetts')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wr2299/48.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[22]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[22 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Michigan')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-64-4c4a0341afb8> in <module>()
#      40 data = [trace, trace1]
#      41
# ---> 42 py.iplot(data, filename='Michigan')
#      43
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ...

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[23]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[23 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Minnesota')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-65-e2cb6cfb5bde> in <module>()
#      40 data = [trace, trace1]
#      41
# ---> 42 py.iplot(data, filename='Minnesta')
#      43
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ...

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[24]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[24 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Mississippi')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[25]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[25 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Montana')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[26]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[26 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Nebraska')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[27]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[27 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)
#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Nebraska')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[28]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[28 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Nevada')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[29]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[29 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='New Hampshire')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[30]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[30 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='New Jersey')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[31]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[31 + x*52]]

deathsFinal
# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='New Mexico')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[32]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[32 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='New York')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[33]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[33 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='North Carolina')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[34]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[34 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='North Dakota')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[35]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[35 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]
py.iplot(data, filename='Ohio')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[41]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[41 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='South Dakota')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[36]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[36 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Oklahoma')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[37]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[37 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Oregon')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[38]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[38 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Pennsylvania')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[39]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[39 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Rhode Island')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[40]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[40 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='South Carolina')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[42]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[42 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Tennessee')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[43]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[43 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Texas')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[44]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[44 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Utah')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[45]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[45 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Vermont')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[46]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[46 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Virginia')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[47]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[47 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Washington')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[48]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[48 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='West Virginia')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[49]

statePrescriptions = stateInfo[3:14]

statePrescriptions

#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[49 + x*52]]

deathsFinal


# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Wisconsin')

# %%
# Create random data with numpy
import numpy as np

year = ['2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016',]


stateInfo = prescriptionsTable.loc[50]

statePrescriptions = stateInfo[3:14]

statePrescriptions


#deaths array
stateDeath = deathsTable['Crude Rate']

deathsFinal = []

for x in range(9): 
    deathsFinal = deathsFinal + [stateDeath.loc[50 + x*52]]

deathsFinal

# Create a trace
trace = go.Scatter(
    x = year,
    y = statePrescriptions,
    name = 'state prescriptions'
    
)

#crude death rate plot
trace1 = go.Scatter(
    x = year,
    y = deathsFinal,
    name = 'deaths'
)

data = [trace, trace1]

py.iplot(data, filename='Wyoming')
